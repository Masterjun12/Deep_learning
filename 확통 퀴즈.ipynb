# %% [markdown]
# ## 확률과 통계 Quiz1: 20210518
# 답안은 www,webhard.co.kr, ID: lindsey, PW: start<br>
# 올리기전용, 확률통계개론/Quiz1 답안제출 폴더에 업로드<br>
# 답안 파일 이름 작성방법: 확률통계개론_quiz1_학생이름_학번.ipynb로 작성<br>

# %% [markdown]
# 다음과 같은 주사위를 던지는 시행이 있다

# %%
import numpy as np
r = []
for i in range(10):
    r.append(random.randint(1,6))

print('array =',[r])
# Out:
# array = [[2, 4, 6, 5, 2, 3, 3, 1, 1, 4]]

# %% [markdown]
# (문제 2)
# 주사위의 각 눈금이 나타나는 빈도를 막대그래프로 그리시오

# %%
import random
import matplotlib.pyplot as plt
dice = []
for i in range(10) :
    dice.append(random.randint(1,6))
print(dice)
plt.hist(dice, bins=6)
plt.show()
# Out:
# [6, 2, 5, 6, 6, 5, 2, 5, 3, 1]

# %% [markdown]
# (문제 3)
# 위의 주사위는 확률함수인가? 그 이유를 설명하시오

# %% [markdown]
# 시행에 의한 확률변수를 가진 함수 이기 때문...

# %% [markdown]
# (문제 4)
# 위의 주사위를 이용하여 sample을 각각 10개, 100개 1000개를 구하여 표본평균을 계산하시오
# 이때 표본평균의 변수이름은 mean_10, mean_100, mean_1000으로 하시오

# %%
import random
import numpy as np

dice = []
for i in range(10) :
    dice.append(random.randint(1,6))

dice = np.array([dice])
mean10 = dice.mean()
print(mean10)

dice = []
for i in range(100) :
    dice.append(random.randint(1,6))

dice = np.array([dice])
mean100 = dice.mean()
print(mean100)

dice = []
for i in range(1000) :
    dice.append(random.randint(1,6))

dice = np.array([dice])
mean1000 = dice.mean()
print(mean1000)
# Out:
# 4.2
# 3.64
# 3.581

# %% [markdown]
# (문제 5)
# 위의 주사위를 이용하여 sample을 각각 10개, 100개 1000개를 구하여 표본분산을 계산하시오
# 이때 표본분산의 변수이름은 var_10, var_100, var_1000으로 하시오

# %%
import random
import numpy as np

dice = []
for i in range(10) :
    dice.append(random.randint(1,6))

dice = np.array([dice])
var_10 = dice.var()
print(var_10)

dice = []
for i in range(100) :
    dice.append(random.randint(1,6))

dice = np.array([dice])
var_100 = dice.var()
print(var_100)

dice = []
for i in range(1000) :
    dice.append(random.randint(1,6))

dice = np.array([dice])
var_1000 = dice.var()
print(var_1000)
# Out:
# 2.6400000000000006
# 2.7875
# 2.9192390000000006

# %% [markdown]
# (문제 6)
# 위의 주사위를 이용하여 sample을 10개 만든 데이터의 변수명을 sample_10 라고할 때  sample_10을 오름차순으로 정리한 데이터를 출력하시오

# %%
def sample_10_():
    import random
    dice = []
    for i in range(10):
        dice.append(random.randint(1,6))
    
dice.reverse()
print('array =',[dice])
# Out:
# array = [[5, 4, 1, 6, 6, 6, 6, 3, 2, 3]]

# %% [markdown]
# (문제 7)
# sample_10_order의 중앙값(median)을 구하시오

# %%
def sample_10_():
    import random
    dice = []
    for i in range(10):
        dice.append(random.randint(1,6))
        return(i)
        x = np.madian(i)
print(x)
# Out:
# 9

# %% [markdown]
# (문제 8)
# sample_10을 표본평균과 표준편차를 이용하여 표준화한 데이터 z_10을 출력하시오

# %%
# Out:
# array([-0.38924947,  0.38924947,  1.16774842, -0.38924947,  1.16774842,
#         0.38924947, -1.16774842, -1.94624736,  1.16774842, -0.38924947])

# %% [markdown]
# (문제 9)
# z_10 의 표본평균과 표준편차를 구하고 시오

# %%
# Out:
# (-1.6653345369377347e-17, 1.0)
